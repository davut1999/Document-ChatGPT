# %% [markdown]
# <a href="https://colab.research.google.com/github/davut1999/Document-ChatGPT/blob/main/text_gcn_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://gitee.com/zrpNUDT/Text-GCN.git
# Out:
# Cloning into 'Text-GCN'...
# remote: Enumerating objects: 161, done.
# remote: Counting objects: 100% (161/161), done.
# remote: Compressing objects: 100% (89/89), done.
# remote: Total 161 (delta 93), reused 113 (delta 66), pack-reused 0
# Receiving objects: 100% (161/161), 24.50 MiB | 2.41 MiB/s, done.
# Resolving deltas: 100% (93/93), done.

# %%
# %cd Text-GCN/
# Out:
# /content/Text-GCN

# %%
# !pip install klepto
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.4/80.4 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 12.7 MB/s eta 0:00:00
# ...

# %%
# !pip install torch_geometric
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.6/661.6 kB 12.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for torch_geometric: filename=torch_geometric-2.3.1-py3-none-any.whl size=910459 sha256=549767eefee9f86aa3b1ebfaefefdc1a90caf497be1ed4837615e38d13b6d155
#   Stored in directory: /root/.cache/pip/wheels/ac/dc/30/e2874821ff308ee67dcd7a66dbde912411e19e35a1addda028
# Successfully built torch_geometric
# ...

# %%
# !pip install torch_scatter
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.6/107.6 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for torch_scatter: filename=torch_scatter-2.1.1-cp310-cp310-linux_x86_64.whl size=489401 sha256=6f229c36293bc8ae4b4b97d6c61440dc13bfecc73a84eb5ae074107855440204
#   Stored in directory: /root/.cache/pip/wheels/ef/67/58/6566a3b61c6ec0f2ca0c2c324cd035ef2955601f0fb3197d5f
# Successfully built torch_scatter
# ...

# %%
# !python main.py --early_stop
# Out:
# Hallo labelist und num_labels
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# # Yeni Bölüm

# %%
# !python prep_data.py
# Out:
# clean dataya girdin
# min_len : 0
# max_len : 35
# average_len : 11.980120030007502

# %%
import sys
print(sys.version)
# Out:
# 3.10.11 (main, Apr  5 2023, 14:15:10) [GCC 9.4.0]
